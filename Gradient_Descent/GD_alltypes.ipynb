# %% [markdown]
# ## IMPLEMENTING ALL GRADIENT DESCENT VARIATIONS FROM SCRATCH

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(['ggplot'])

# %%
X = 2*np.random.rand(100,1)
y = 4 + 3*X + np.random.randn(100,1)

# %%
plt.scatter(X,y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('DATA')
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
X_b = np.c_[np.ones((100,1)),X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[4.06771545]
#  [2.9375687 ]]

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2,1)),X_new]
y_predict = X_new_b.dot(theta_best)

# %%
print(X_new_b)
# Out:
# [[1. 0.]
#  [1. 2.]]

# %%
y_predict
# Out:
# array([[4.06771545],
#        [9.94285285]])

# %%
plt.plot(X_new,y_predict,'r-')
plt.plot(X,y,'b.')
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0,2,0,15])
# Out:
# (0.0, 2.0, 0.0, 15.0)
