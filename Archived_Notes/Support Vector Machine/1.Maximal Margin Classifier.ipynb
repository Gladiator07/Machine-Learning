# %% [markdown]
# Support Vector Machines are perhaps one of the most popular and talked about machine learning algorithms.
#
# They were extremely popular around the time they were developed in the 1990s and continue to be the go-to method for a high-performing algorithm with little tuning.

# %% [markdown]
# ##  Maximal Margin Classifier

# %% [markdown]
# The Maximal-Margin Classifier is a hypothetical classifier that best explains how SVM works in practice

# %% [markdown]
# The support vector machine is a generalization of a classifier called maximal margin classifier. The maximal margin classifier is simple, but it cannot be applied to the majority of datasets, since the classes must be separated by a linear boundary.

# %% [markdown]
# The numeric input variables (x) in your data (the columns) form an n-dimensional space. For example, if you had two input variables, this would form a two-dimensional space.

# %% [markdown]
# Maximal Margin Classifier method relies on seperating classes using a hyperplane

# %% [markdown]
# ### What is a Hyperplane?

# %% [markdown]
# In a p-dimensional space, a hyperplane is a flat affine subspace of dimension p-1

# %% [markdown]
# Scared?? Let's break it down....

# %% [markdown]
# A hyperplane is a line that splits the input variable space. In SVM, a hyperplane is selected to best separate the points in the input variable space by their class, either class 0 or class 1. In two-dimensions you can visualize this as a line and in a 3D space a hyperplane can be visualized as a flat plane.
# and let’s assume that all of our input points can be completely separated by this line. So mathematically a hyperplane equation of a 2D space would look like this:

# %% [markdown]
# B0 + (B1 * X1) + (B2 * X2) = 0

# %% [markdown]
# Where the coefficients (B1 and B2) that determine the slope of the line and the intercept (B0) are found by the learning algorithm, and X1 and X2 are the two input variables.

# %% [markdown]
# So, what can you expect from this mathematical equation???

# %% [markdown]
# You can make classifications using this line. By plugging in input values into the line equation, you can calculate whether a new point is above or below the line.
#
# - Above the line, the equation returns a value greater than 0 and the point belongs to the first class (class 0)
# - Below the line, the equation returns a value less than 0 and the point belongs to the second class (class 1)
# - A value close to the line returns a value close to zero and the point may be difficult to classify
# - If the magnitude of the value is large, the model may have more confidence in the prediction

# %% [markdown]
# To make the above equation more generalized, we can write it as follows for p number of features (i.e. p dimensional space)

# %% [markdown]
# ![image.png](attachment:8f714798-2cd2-4a85-adf3-11146aa13c62.png)

# %% [markdown]
# If X satisfies the equation above, then the point lies on the plane

# %% [markdown]
# To give you more idea on how a hyperplane looks like below are the hyperplanes in 2D and 3D space:

# %% [markdown]
# ![image.png](attachment:f349144e-9a69-4c00-8e49-3067c5c5ca78.png)

# %% [markdown]
# ![image.png](attachment:e369d7ce-fd71-45be-91b6-f31341fdfae4.png)

# %% [markdown]
# The distance between the line and closest data points is referred to as margin. The best or optimal line that can seperate the two classes is the largest margin line. This is called Maximal Margin Hyperplane

# %% [markdown]
# The margin is calculated as the perpendicular distance from the line to only the closest points. Only these points are relevant in defining the line and in the construction of the classifier. These points are called the support vectors. They support or define the hyperplane.
#
# The hyperplane is learned from training data using an optimization procedure that maximizes the margin.

# %% [markdown]
# ![image.png](attachment:5b37d593-9060-4239-ba31-c46b656eeafe.png)

# %% [markdown]
# You can think of large margin classifier as fitting the widest possible street (here, represented by parallel dashed line)

# %% [markdown]
# Notice that adding more training instances “off the street” will not affect the decision boundary at all: it is fully determined (or “supported”) by the instances located on the edge of the street. These instances are called the support vectors (they are circled in Figure 5-1)

# %% [markdown]
# But in real life dataset it is almost impossible to fit large margin to the data. So, we use a classifier called as Soft Margin Classifier which is discussed in
# [subsequent notebook](https://github.com/Gladiator07/Machine-Learning-Complete/blob/master/Support%20Vector%20Machine/2.Soft%20Margin%20Classifier.ipynb)
